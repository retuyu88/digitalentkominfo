# %% [markdown]
# <a href="https://colab.research.google.com/github/retuyu88/digitalentkominfo/blob/master/Copy_of_exercise_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv'
    
car = pd.read_csv(url)
car.shape
car
# Out:
#     index        company   body-style  ...  horsepower  average-mileage    price
# 0       0    alfa-romero  convertible  ...         111               21  13495.0
# 1       1    alfa-romero  convertible  ...         111               21  16500.0
# 2       2    alfa-romero    hatchback  ...         154               19  16500.0
# 3       3           audi        sedan  ...         102               24  13950.0
# 4       4           audi        sedan  ...         115               18  17450.0
# 5       5           audi        sedan  ...         110               19  15250.0
# 6       6           audi        wagon  ...         110               19  18920.0
# 7       9            bmw        sedan  ...         101               23  16430.0
# 8      10            bmw        sedan  ...         101               23  16925.0
# 9      11            bmw        sedan  ...         121               21  20970.0
# 10     13            bmw        sedan  ...         182               16  30760.0
# ...

# %% [markdown]
# ### Step 4. Check whether null value exist in the Dataframe

# %%
car.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %% [markdown]
# ### Step 5. Cleaning data

# %%
#cara 1 cleaning data adalah dengan menghapus data yang mengandung nilai kosong/NaN
#a = car.dropna(axis=0)
#assign new value
#mean = car.loc[:,'price'].mean()
b = car.fillna(car.loc[:,'price'].mean(),inplace=True)
car
# Out:
#     index        company   body-style  ...  horsepower  average-mileage    price
# 0       0    alfa-romero  convertible  ...         111               21  13495.0
# 1       1    alfa-romero  convertible  ...         111               21  16500.0
# 2       2    alfa-romero    hatchback  ...         154               19  16500.0
# 3       3           audi        sedan  ...         102               24  13950.0
# 4       4           audi        sedan  ...         115               18  17450.0
# 5       5           audi        sedan  ...         110               19  15250.0
# 6       6           audi        wagon  ...         110               19  18920.0
# 7       9            bmw        sedan  ...         101               23  16430.0
# 8      10            bmw        sedan  ...         101               23  16925.0
# 9      11            bmw        sedan  ...         121               21  20970.0
# 10     13            bmw        sedan  ...         182               16  30760.0
# ...

# %% [markdown]
# ### Step 4. From given data set print first five rows

# %%
car.head(5)
# Out:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
# 1      1  alfa-romero  convertible  ...         111               21  16500.0
# 2      2  alfa-romero    hatchback  ...         154               19  16500.0
# 3      3         audi        sedan  ...         102               24  13950.0
# 4      4         audi        sedan  ...         115               18  17450.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Step 5. From given data set print last five rows

# %%
car.tail(5)
car.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %% [markdown]
# ### Step 6. Find the most expensive car company name

# %%
car.loc[car['price'] == car['price'].max()]
# Out:
#     index        company body-style  ...  horsepower  average-mileage    price
# 35     47  mercedes-benz    hardtop  ...         184               14  45400.0
#
# [1 rows x 10 columns]

# %% [markdown]
# ### Step 7. Print All Toyota Cars details

# %%
car.loc[car['company'] == 'toyota']
# Out:
#     index company body-style  ...  horsepower  average-mileage    price
# 48     66  toyota  hatchback  ...          62               35   5348.0
# 49     67  toyota  hatchback  ...          62               31   6338.0
# 50     68  toyota  hatchback  ...          62               31   6488.0
# 51     69  toyota      wagon  ...          62               31   6918.0
# 52     70  toyota      wagon  ...          62               27   7898.0
# 53     71  toyota      wagon  ...          62               27   8778.0
# 54     79  toyota      wagon  ...         156               19  15750.0
#
# [7 rows x 10 columns]

# %% [markdown]
# ### Step 8. Count total cars per company

# %%
car.groupby('company').size()
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64

# %% [markdown]
# ### Step 9. Find each company’s Higesht price car

# %%
#car.loc[car['price'] == car['price'].max()]
car.groupby['company','price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-21c5f250b451> in <module>()
# ----> 1 car.groupby['company','price']
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# ### Step 10. Find the average mileage of each car making company

# %% [markdown]
# ### Step 11. Sort all cars by Price column
