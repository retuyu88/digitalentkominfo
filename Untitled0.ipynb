# %% [markdown]
# <a href="https://colab.research.google.com/github/retuyu88/digitalentkominfo/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = [-0.5,0.1,0.3,0.2,1.4,1.5,1.6,1.7]
x2 = [0.1,0.2,0.4,0.6,1.5,1.1,1.8,1.5]
kelas = [0,0,0,0,1,1,1,1]

import numpy as np

def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    
    # Biases
    self.b1 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    #mencari nilai V
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    return h1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 4000 # number of times to loop through the entire dataset
    a = []
    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)
        
        y_pred = h1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)


        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)

        
        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred  * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred  * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred  * d_h1_d_b1


      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        a.append(loss)
        print("Epoch %d loss: %.3f" % (epoch, loss))
        print("update w1 : %.3f   w2 : %3.f  w0 : %.3f" %(self.w1,self.w2,self.b1))
        
      

# Define dataset
data = np.array([
  [-0.5, 0.1],  # 1
  [0.1, 0.2],   # 2
  [0.3, 0.4],   # 3
  [0.2, 0.6], # 4
  [1.4, 1.5],#5
  [1.5, 1.1],#6
  [1.6, 1.8],#7
  [1.7, 1.5],#8  
])
all_y_trues = np.array([
  0, # 1
  0, # 2
  0, # 3
  0, # 4
  1,
  1,
  1,
  1,
])

# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.149
# update w1 : 0.752   w2 :  -0  w0 : -0.678
# Epoch 10 loss: 0.074
# update w1 : 1.309   w2 :   0  w0 : -0.876
# Epoch 20 loss: 0.055
# update w1 : 1.545   w2 :   0  w0 : -1.179
# Epoch 30 loss: 0.043
# update w1 : 1.720   w2 :   0  w0 : -1.423
# Epoch 40 loss: 0.035
# update w1 : 1.864   w2 :   0  w0 : -1.622
# Epoch 50 loss: 0.029
# update w1 : 1.985   w2 :   1  w0 : -1.788
# Epoch 60 loss: 0.025
# update w1 : 2.091   w2 :   1  w0 : -1.930
# Epoch 70 loss: 0.022
# update w1 : 2.183   w2 :   1  w0 : -2.054
# Epoch 80 loss: 0.020
# update w1 : 2.266   w2 :   1  w0 : -2.163
# Epoch 90 loss: 0.018
# update w1 : 2.341   w2 :   1  w0 : -2.261
# Epoch 100 loss: 0.016
# update w1 : 2.409   w2 :   1  w0 : -2.350
# Epoch 110 loss: 0.015
# update w1 : 2.472   w2 :   1  w0 : -2.431
# Epoch 120 loss: 0.013
# update w1 : 2.530   w2 :   1  w0 : -2.506
# Epoch 130 loss: 0.012
# update w1 : 2.583   w2 :   1  w0 : -2.575
# Epoch 140 loss: 0.012
# ...

# %%
# Make some predictions
data9 = np.array([5, 1.8]) # 
data10 = np.array([2.4, 2.3])  # 
print("9: %.3f" % network.feedforward(data9)) # 0.951 - F
print("10: %.3f" % network.feedforward(data10)) # 0.039 - M
data1 = np.array([-0.5, 0.1])  # 1
data2 = np.array([0.1, 0.2])   # 2
data3 = np.array([0.3, 0.4])   # 3
data4 = np.array([0.2, 0.6]) # 4
data5 = np.array([1.4, 1.5])#5
data6 = np.array([1.5, 1.1])#6
data7 = np.array([1.6, 1.8])#7
data8 = np.array([1.7, 1.5])
print("1: %.3f" % network.feedforward(data1)) # 
print("2: %.3f" % network.feedforward(data2)) # 
print("3: %.3f" % network.feedforward(data3)) # 
print("4: %.3f" % network.feedforward(data4)) # 
print("5: %.3f" % network.feedforward(data5)) # 
print("6: %.3f" % network.feedforward(data6)) # 
print("7: %.3f" % network.feedforward(data7)) # 
print("8: %.3f" % network.feedforward(data8)) #
# Out:
# 9: 1.000
# 10: 1.000
# 1: 0.000
# 2: 0.009
# 3: 0.034
# 4: 0.028
# 5: 0.980
# 6: 0.977
# 7: 0.995
# 8: 0.995

# %%
data2 = np.array([
  [0.2, 0.1],  # 1
  [0.4, 0.5],   # 2
  [0.3, 0.4],   # 3
  [0.2, 0.6], # 4
  [-0.2, 0.8],#5
  [-0.2, -0.7],#6
  [0.7, 0.8],#7
  [0.8, 1.5],#8  
])

# %%
all_y_trues2 = np.array([
  0, # 1
  0, # 2
  0, # 3
  0, # 4
  1,
  1,
  1,
  1,
])

# Train our neural network!
network = OurNeuralNetwork()
network.train(data2, all_y_trues2)
# Out:
# Epoch 0 loss: 0.326
# update w1 : 0.667   w2 :  -2  w0 : 0.775
# Epoch 10 loss: 0.300
# update w1 : 0.707   w2 :  -1  w0 : 0.589
# Epoch 20 loss: 0.281
# update w1 : 0.720   w2 :  -1  w0 : 0.419
# Epoch 30 loss: 0.269
# update w1 : 0.697   w2 :  -1  w0 : 0.269
# Epoch 40 loss: 0.261
# update w1 : 0.649   w2 :  -0  w0 : 0.148
# Epoch 50 loss: 0.257
# update w1 : 0.587   w2 :  -0  w0 : 0.057
# Epoch 60 loss: 0.253
# update w1 : 0.516   w2 :  -0  w0 : -0.011
# Epoch 70 loss: 0.251
# update w1 : 0.442   w2 :   0  w0 : -0.062
# Epoch 80 loss: 0.249
# update w1 : 0.366   w2 :   0  w0 : -0.102
# Epoch 90 loss: 0.247
# update w1 : 0.291   w2 :   0  w0 : -0.134
# Epoch 100 loss: 0.246
# update w1 : 0.217   w2 :   0  w0 : -0.160
# Epoch 110 loss: 0.245
# update w1 : 0.145   w2 :   0  w0 : -0.181
# Epoch 120 loss: 0.244
# update w1 : 0.076   w2 :   0  w0 : -0.200
# Epoch 130 loss: 0.243
# update w1 : 0.009   w2 :   1  w0 : -0.215
# Epoch 140 loss: 0.242
# ...

# %%
import numpy as np

def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
    return o1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 6000 # number of times to loop through the entire dataset

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = sigmoid(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
        d_ypred_d_b3 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
        d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_sigmoid(sum_h2)
        d_h2_d_w4 = x[1] * deriv_sigmoid(sum_h2)
        d_h2_d_b2 = deriv_sigmoid(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron o1
        self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
        self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
        self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))
        print("update w1 : %.3f   w2 : %3.f  B1 : %.3f" %(self.w1,self.w2,self.b1))
        print("update w3 : %.3f   w4 : %3.f  B2 : %.3f" %(self.w3,self.w4,self.b2))
        print("update w5 : %.3f   w6 : %3.f  B3 : %.3f" %(self.w5,self.w6,self.b3))

# Define dataset
data = np.array([
  [0.2, 0.1],  # 1
  [0.4, 0.5],   # 2
  [0.3, 0.4],   # 3
  [0.2, 0.6], # 4
  [-0.2, 0.8],#5
  [-0.2, -0.7],#6
  [0.7, 0.08],#7
  [0.8, 1.5],#8  
])
all_y_trues = np.array([
  0, # 1
  0, # 2
  0, # 3
  0, # 4
  1,
  1,
  1,
  1,
])
# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.270
# update w1 : -0.493   w2 :  -1  B1 : 0.706
# update w3 : 0.714   w4 :  -1  B2 : 0.059
# update w5 : 0.001   w6 :   0  B3 : -0.662
# Epoch 10 loss: 0.251
# update w1 : -0.492   w2 :  -1  B1 : 0.705
# update w3 : 0.717   w4 :  -1  B2 : 0.064
# update w5 : 0.160   w6 :   0  B3 : -0.319
# Epoch 20 loss: 0.250
# update w1 : -0.493   w2 :  -1  B1 : 0.697
# update w3 : 0.715   w4 :  -1  B2 : 0.052
# update w5 : 0.189   w6 :   0  B3 : -0.224
# Epoch 30 loss: 0.250
# update w1 : -0.495   w2 :  -1  B1 : 0.685
# update w3 : 0.711   w4 :  -1  B2 : 0.035
# update w5 : 0.185   w6 :   0  B3 : -0.194
# Epoch 40 loss: 0.250
# update w1 : -0.498   w2 :  -1  B1 : 0.674
# update w3 : 0.707   w4 :  -1  B2 : 0.016
# update w5 : 0.173   w6 :   0  B3 : -0.180
# Epoch 50 loss: 0.250
# update w1 : -0.500   w2 :  -1  B1 : 0.663
# update w3 : 0.702   w4 :  -1  B2 : -0.004
# update w5 : 0.161   w6 :   0  B3 : -0.170
# Epoch 60 loss: 0.250
# update w1 : -0.502   w2 :  -1  B1 : 0.652
# ...

# %%
test1 = np.array([-7, -3]) # 128 pounds, 63 inches
test2 = np.array([20, 2])  # 155 pounds, 68 inches
print("Emily: %.3f" % network.feedforward(test1)) # 0.951 - F
print("Frank: %.3f" % network.feedforward(test2)) # 0.039 - M
# Out:
# Emily: 0.987
# Frank: 0.992

# %%
for i in data:
  print(network.feedforward(i))
# Out:
# 0.037838788994491036
# 0.013626638072424058
# 0.01303297940853064
# 0.04188722109541674
# 0.9590668536798587
# 0.9778322863311176
# 0.9652998038034657
# 0.9727385516580209

# %%
import numpy as np

def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = max([0,x])
  return fx * (1 - fx)

def rectified(x):
	return max(0.0, x)

def deriv_rectified(x): #turunan dari reLU = 1
  return 1

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)

  *** DISCLAIMER ***:
  The code below is intended to be simple and educational, NOT optimal.
  Real neural net code looks nothing like this. DO NOT use this code.
  Instead, read/run it to understand how this specific network works.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
    return o1

  def train(self, data, all_y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 1000 # number of times to loop through the entire dataset

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = rectified(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = rectified(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
        d_ypred_d_b3 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
        d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_rectified(sum_h1)
        d_h1_d_w2 = x[1] * deriv_rectified(sum_h1)
        d_h1_d_b1 = deriv_rectified(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_rectified(sum_h2)
        d_h2_d_w4 = x[1] * deriv_rectified(sum_h2)
        d_h2_d_b2 = deriv_rectified(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron o1
        self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
        self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
        self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))
        print("update w1 : %.3f   w2 : %3.f  B1 : %.3f" %(self.w1,self.w2,self.b1))
        print("update w3 : %.3f   w4 : %3.f  B2 : %.3f" %(self.w3,self.w4,self.b2))
        print("update w5 : %.3f   w6 : %3.f  B3 : %.3f" %(self.w5,self.w6,self.b3))

# Define dataset
data = np.array([
  [0.2, 0.1],  # 1
  [0.4, 0.5],   # 2
  [0.3, 0.4],   # 3
  [0.2, 0.6], # 4
  [-0.2, 0.8],#5
  [-0.2, -0.7],#6
  [0.7, 0.08],#7
  [0.8, 1.5],#8  
])
all_y_trues = np.array([
  0, # 1
  0, # 2
  0, # 3
  0, # 4
  1,
  1,
  1,
  1,
])
# Train our neural network!
network = OurNeuralNetwork()
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.255
# update w1 : 1.014   w2 :  -1  B1 : 0.857
# update w3 : -0.948   w4 :   0  B2 : 0.610
# update w5 : 1.350   w6 :   1  B3 : -1.077
# Epoch 10 loss: 0.255
# update w1 : 1.000   w2 :  -1  B1 : 0.784
# update w3 : -0.953   w4 :   0  B2 : 0.584
# update w5 : 1.388   w6 :   0  B3 : -1.128
# Epoch 20 loss: 0.255
# update w1 : 1.025   w2 :  -1  B1 : 0.741
# update w3 : -0.945   w4 :   0  B2 : 0.569
# update w5 : 1.447   w6 :   0  B3 : -1.156
# Epoch 30 loss: 0.256
# update w1 : 1.062   w2 :  -1  B1 : 0.702
# update w3 : -0.934   w4 :   0  B2 : 0.558
# update w5 : 1.502   w6 :   0  B3 : -1.181
# Epoch 40 loss: 0.257
# update w1 : 1.101   w2 :  -1  B1 : 0.669
# update w3 : -0.924   w4 :  -0  B2 : 0.549
# update w5 : 1.550   w6 :   0  B3 : -1.202
# Epoch 50 loss: 0.257
# update w1 : 1.135   w2 :  -1  B1 : 0.641
# update w3 : -0.916   w4 :  -0  B2 : 0.542
# update w5 : 1.590   w6 :   0  B3 : -1.220
# Epoch 60 loss: 0.258
# update w1 : 1.163   w2 :  -1  B1 : 0.619
# ...

# %%
for i in data:
  print(network.feedforward(i))
# Out:
# 0.5783610429831646
# 0.6205083586336084
# 0.6144999638726104
# 0.6493444677421724
# 0.6916656211302228
# 0.5103830044453721
# 0.5298754405726368
# 0.6998450780805051
